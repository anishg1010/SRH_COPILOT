# %%
from langchain_community.document_loaders import PyPDFLoader
# Out:
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_8288\4175148793.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
paths = [
    r"database/docx/2601_Beurlaubung.pdf",
    r"database\docx\2601_Studiengang_Standortwechsel_ab_2_Semester.pdf",
    r"database\docx\2601_Studiengang_Standortwechsel_Studienstart.pdf",
    r"database\docx\240205 Leitbild für Lehren und Lernen 2024 final.pdf",
    r"database\docx\260331_FAQ_Avaya Hotline_StS.pdf",
    r"database\docx\260410_AC5 Handbuch – Anleitungen Studierendenservice.pdf"
]


for doc in paths:
    loader = PyPDFLoader(doc)
    documents = loader.load()

    print(documents[0].metadata)
# Out:
# {'producer': 'Microsoft® Word für Microsoft 365', 'creator': 'Microsoft® Word für Microsoft 365', 'creationdate': '2026-01-12T14:44:39+01:00', 'title': 'Besprechungsprotokoll: Teamleiter:innen-Call', 'author': 'Graupe-Fröhlich, Marika (dab)', 'moddate': '2026-01-12T14:44:39+01:00', 'source': 'database/docx/2601_Beurlaubung.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}
# {'producer': 'Microsoft® Word für Microsoft 365', 'creator': 'Microsoft® Word für Microsoft 365', 'creationdate': '2026-01-12T14:48:58+01:00', 'title': 'Besprechungsprotokoll: Teamleiter:innen-Call', 'author': 'Graupe-Fröhlich, Marika (dab)', 'moddate': '2026-01-12T14:48:58+01:00', 'source': 'database\\docx\\2601_Studiengang_Standortwechsel_ab_2_Semester.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}
# ...
